# %% [markdown]
# # Exploratory Analysis for Social Media Trails Project

# %% [markdown]
# ### Import required libraries

# %%
from __future__ import (absolute_import, division, print_function)
import os


import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('bmh')

from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
from geopandas import GeoSeries, GeoDataFrame
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
# Assign  shapefile to variable
pud_results = gpd.read_file("data/pud_results_hex.shp")
pud_results.head()

ranier = gpd.read_file("data/rainierNP_boundary.shp")
pud_results.head()
pud_results_nonzero = pud_results[(pud_results.T != 0).any()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-cd27c1fa332a> in <module>()
#       6 pud_results.head()
#       7 pud_results_nonzero = pud_results[(pud_results.T != 0).any()]
# ----> 8 df = df[(df.T != 0).any()]
#
# NameError: name 'df' is not defined

# %%
pud_results.plot(cmap = 'inferno',categorical = True, column = "PUD_AUG" ,figsize=(10, 10), legend = True, scheme = 'Fisher_Jenks')

# %%
pud_results['log_AVG'] = np.log(pud_results[:'PUD_YR_AVG'])

# %%
pud_results.plot(cmap = 'inferno',categorical = True, column = "log_AVG" ,figsize=(10, 10), legend = True, scheme = 'Fisher_Jenks')

# %%
pud_results['log_AVG'].hist()

# %%
pud_results_nonzero.plot(cmap = 'inferno',categorical = True, column = "PUD_YR_AVG" ,figsize=(10, 10), legend = True, scheme = 'Fisher_Jenks')
